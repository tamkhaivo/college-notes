# %%
# Home Prices in Monroe Township, NJ (USA) with Ordinal Encoding
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import OneHotEncoder

le = LabelEncoder()
ohe = OneHotEncoder()

# %%
# 1. Load the data from the CSV file into a pandas DataFrame
csv_file_path = '/Users/tvo/Library/CloudStorage/OneDrive-CaliforniaStateUniversity,Sacramento/college-notes/CSC 180/homeprices3.csv'

df = pd.read_csv(csv_file_path)
print("Original Data:")
print(df)
print("-" * 30)
# Out:
# Original Data:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000
# ------------------------------

# %%
# 2. Handle missing data - No Missing Data - SKIPPING
# We'll fill the missing 'bedrooms' value with the median of the column.
# median_bedrooms = math.floor(df.bedrooms.median())
# df.bedrooms = df.bedrooms.fillna(median_bedrooms)
# print("\nData after handling missing values:")
# print(df)
# print("-" * 30)

# %%
# Update Schema with categorical 'town' feature with Ordinal Encoding
print("\nProcessing data with 'town' as a categorical feature using Ordinal Encoding.")
df_town_ordinal = df
df_town_ordinal.town = le.fit_transform(df_town_ordinal.town)
print("\nData after town with Ordinal Encoding :")
print(df_town_ordinal)
print("-" * 30)
# Out:
# Processing data with 'town' as a categorical feature using Ordinal Encoding.
#
# Data after town with Ordinal Encoding :
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000
# ------------------------------

# %%
# Update Schema with categorical 'town' feature with One Hot Encoding
print("\nProcessing data with 'town' as a categorical feature using One Hot Encoding Encoding.")
df_town_ohe = df
df_town_ohe = ohe.fit_transform(df[['town']])

# 2. Get the new column names from the encoder (THIS IS THE FIX)

new_cols = ohe.get_feature_names_out(['town'])

# 3. Create the new DataFrame with the correct column names
ohe_df = pd.DataFrame(df_town_ohe, columns=new_cols)

# 4. Join it with your original data
df_final = df.join(ohe_df).drop('town', axis=1)

print("\nData after town with One Hot Encoding :")
print(df_final)
print("-" * 30)
# Out:
# Processing data with 'town' as a categorical feature using One Hot Encoding Encoding.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 print("\nProcessing data with 'town' as a categorical feature using One Hot Encoding Encoding.")
#       3 df_town_ohe = df
# ----> 4 df_town_ohe = ohe.fit_transform(df[['town']])
#       6 # 2. Get the new column names from the encoder (THIS IS THE FIX)
#       8 new_cols = ohe.get_feature_names_out(['town'])
#
# NameError: name 'ohe' is not defined

# %%
# 3. Separate features (X) and the target variable (y)
target = 'price'

# Dummy Variable Dropped
features_dummy_variable_dropped = [col for col in df_final.columns if col != 'price']
X_dummy_variable_dropped = df_final[features_dummy_variable_dropped]

# Additional Column for Dummy Variable
features_with_dummy = [col for col in df_processed.columns if col != 'price']
X_with_dummy = df_processed[features_with_dummy]

y = df_final[target]

# %%
# 4. Create and train the Linear Regression model
model_dummy_variable_dropped = LinearRegression()
model_dummy_variable_dropped.fit(X_dummy_variable_dropped, y)


model_with_dummy = LinearRegression()
model_with_dummy.fit(X_with_dummy, y)
# Out:
# LinearRegression()

# %%
# 5. Display the results of the trained model
# The coefficients show the impact of each feature on the price.
print("\nModel_dummy_variable_dropped Coefficients:")
for feature, coef in zip(features_dummy_variable_dropped, model_dummy_variable_dropped.coef_):
    print(f"  - {feature}: {coef:.2f}")
    
# The intercept is the base price if all features were zero.
print(f"\nModel_dummy_variable_dropped Intercept: {model_dummy_variable_dropped.intercept_:.2f}")
print("-" * 30)

print("\nModel_with_dummy Coefficients:")
for feature, coef in zip(features_with_dummy, model_with_dummy.coef_):
    print(f"  - {feature}: {coef:.2f}")
    
# The intercept is the base price if all features were zero.
print(f"\nModel_with_dummy Intercept: {model_with_dummy.intercept_:.2f}")
print("-" * 30)
# Out:
# Model_dummy_variable_dropped Coefficients:
#   - area: 126.90
#   - town_monroe township: -40013.98
#   - town_robinsville: -14327.56
#
# Model_dummy_variable_dropped Intercept: 249790.37
# ------------------------------
#
# Model_with_dummy Coefficients:
#   - area: 126.90
#   - town_monroe township: -21900.13
#   - town_robinsville: 3786.28
#   - town_west windsor: 18113.85
#
# Model_with_dummy Intercept: 231676.52
# ------------------------------

# %%
# 6. Use the model to make predictions
print("\nExample Predictions with Dummy Variable Dropped:")
price_monroe = model_dummy_variable_dropped.predict([[3400, 1, 0]])
print(f"  - Predicted price for a 3400 sq ft house in Monroe Township: ${price_monroe[0]:,.2f}")

price_robbinsville = model_dummy_variable_dropped.predict([[2800, 0, 1]])
print(f"  - Predicted price for a 2800 sq ft house in Robbinsville: ${price_robbinsville[0]:,.2f}")

price_west_windsor = model_dummy_variable_dropped.predict([[3100, 0, 0]]) # Base case
print(f"  - Predicted price for a 3100 sq ft house in West Windsor: ${price_west_windsor[0]:,.2f}")

# 6. Use the model to make predictions
print("\nExample Predictions with Dummy Variable:")
price_monroe = model_with_dummy.predict([[3400, 1, 0, 0]])
print(f"  - Predicted price for a 3400 sq ft house in Monroe Township: ${price_monroe[0]:,.2f}")

price_robbinsville = model_with_dummy.predict([[2800, 0, 1, 0]])
print(f"  - Predicted price for a 2800 sq ft house in Robbinsville: ${price_robbinsville[0]:,.2f}")

price_west_windsor = model_with_dummy.predict([[3100, 0, 0 , 1]]) # Base case
print(f"  - Predicted price for a 3100 sq ft house in West Windsor: ${price_west_windsor[0]:,.2f}")
# Out:
# Example Predictions with Dummy Variable Dropped:
#   - Predicted price for a 3400 sq ft house in Monroe Township: $641,227.69
#   - Predicted price for a 2800 sq ft house in Robbinsville: $590,775.64
#   - Predicted price for a 3100 sq ft house in West Windsor: $643,172.44
#
# Example Predictions with Dummy Variable:
#   - Predicted price for a 3400 sq ft house in Monroe Township: $641,227.69
#   - Predicted price for a 2800 sq ft house in Robbinsville: $590,775.64
#   - Predicted price for a 3100 sq ft house in West Windsor: $643,172.44
# /opt/homebrew/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...
