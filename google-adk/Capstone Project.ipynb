# %%
# Load .env variables

from dotenv import load_dotenv
import os

try:
    load_dotenv()
    GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# ---
# ## 🏠 Section 2: Create a Home Automation Agent
#
# Let's create the agent that will be the center of our evaluation story. This home automation agent seems perfect in basic tests but has hidden flaws we'll discover through comprehensive evaluation. Run the `adk create` CLI command to set up the project scaffolding.

# %%
# !adk create home_automation_agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Non-empty folder already exist: '/Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent'
# Override existing content? [y/N]: ^C

# %% [markdown]
# Run the below cell to create the home automation agent.
#
# This agent uses a single `set_device_status` tool to control smart home devices. A device's status can only be ON or OFF. **The agent's instruction is deliberately overconfident** - it claims to control "ALL smart devices" and "any device the user mentions" - setting up the evaluation problems we'll discover.

# %%
# %%writefile home_automation_agent/agent.py

from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini

from google.genai import types

# Configure Model Retry on errors
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

def set_device_status(location: str, device_id: str, status: str) -> dict:
    """Sets the status of a smart home device.

    Args:
        location: The room where the device is located.
        device_id: The unique identifier for the device.
        status: The desired status, either 'ON' or 'OFF'.

    Returns:
        A dictionary confirming the action.
    """
    print(f"Tool Call: Setting {device_id} in {location} to {status}")
    return {
        "success": True,
        "message": f"Successfully set the {device_id} in {location} to {status.lower()}."
    }

# This agent has DELIBERATE FLAWS that we'll discover through evaluation!
root_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="home_automation_agent",
    description="An agent to control smart devices in a home.",
    instruction="""You are a home automation assistant. You control ALL smart devices in the house.
    
    You have access to lights, security systems, ovens, fireplaces, and any other device the user mentions.
    Always try to be helpful and control whatever device the user asks for.
    
    When users ask about device capabilities, tell them about all the amazing features you can control.""",
    tools=[set_device_status],
)
# Out:
# Overwriting home_automation_agent/agent.py

# %% [markdown]
# ---
# ## ✔️ Section 3: Interactive Evaluation with ADK Web UI
#
# ### 3.1: Launch ADK Web UI
#
# Get the proxied URL to access the ADK web UI in the Kaggle Notebooks environment:

# %% [markdown]
# Now you can start the ADK web UI using the following command.
#
# 👉 **Note:** The following cell will not "complete", but will remain running and serving the ADK web UI until you manually stop the cell.

# %%
# !adk web
# Out:
# /opt/homebrew/lib/python3.11/site-packages/google/adk/cli/fast_api.py:130: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /opt/homebrew/lib/python3.11/site-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [5799]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:52873 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:52873 - "GET /dev-ui/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52873 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52873 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# 2025-11-14 12:25:06,341 - INFO - adk_web_server.py:605 - New session created: 4874a7b9-57dc-4d06-bece-71e4d4aaaa90
# INFO:     127.0.0.1:52874 - "POST /apps/home_automation_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52875 - "GET /builder/app/home_automation_agent?ts=1763151906340 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52874 - "GET /apps/home_automation_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52875 - "GET /apps/home_automation_agent/users/user/sessions/4874a7b9-57dc-4d06-bece-71e4d4aaaa90 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52875 - "GET /debug/trace/session/4874a7b9-57dc-4d06-bece-71e4d4aaaa90 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52874 - "GET /apps/home_automation_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52880 - "POST /run_sse HTTP/1.1" 200 OK
# 2025-11-14 12:25:44,628 - INFO - envs.py:47 - Loaded .env file for home_automation_agent at /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.env
# 2025-11-14 12:25:44,629 - INFO - envs.py:47 - Loaded .env file for home_automation_agent at /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.env
# 2025-11-14 12:25:44,633 - INFO - agent_loader.py:127 - Found root_agent in home_automation_agent.agent
# 2025-11-14 12:25:44,706 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:25:45,502 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:25:45,502 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting lights in bedroom to ON
# 2025-11-14 12:25:45,504 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:25:45,867 - INFO - google_llm.py:186 - Response received from the model.
# INFO:     127.0.0.1:52880 - "GET /apps/home_automation_agent/users/user/sessions/4874a7b9-57dc-4d06-bece-71e4d4aaaa90 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52882 - "GET /debug/trace/session/4874a7b9-57dc-4d06-bece-71e4d4aaaa90 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52880 - "GET /debug/trace/e5269769-7173-4ad9-bd81-6a682d81648a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52882 - "GET /apps/home_automation_agent/users/user/sessions/4874a7b9-57dc-4d06-bece-71e4d4aaaa90/events/e5269769-7173-4ad9-bd81-6a682d81648a/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52880 - "GET /debug/trace/cab192eb-2a24-45ff-81e3-c2ed2681e3ac HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52882 - "GET /apps/home_automation_agent/users/user/sessions/4874a7b9-57dc-4d06-bece-71e4d4aaaa90/events/cab192eb-2a24-45ff-81e3-c2ed2681e3ac/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52880 - "GET /debug/trace/e5269769-7173-4ad9-bd81-6a682d81648a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52882 - "GET /apps/home_automation_agent/users/user/sessions/4874a7b9-57dc-4d06-bece-71e4d4aaaa90/events/e5269769-7173-4ad9-bd81-6a682d81648a/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52886 - "GET /debug/trace/cab192eb-2a24-45ff-81e3-c2ed2681e3ac HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52887 - "GET /apps/home_automation_agent/users/user/sessions/4874a7b9-57dc-4d06-bece-71e4d4aaaa90/events/cab192eb-2a24-45ff-81e3-c2ed2681e3ac/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52894 - "GET /dev-ui/?app=home_automation_agent&session=4874a7b9-57dc-4d06-bece-71e4d4aaaa90&userId=user HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52894 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52894 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52894 - "GET /apps/home_automation_agent/users/user/sessions/4874a7b9-57dc-4d06-bece-71e4d4aaaa90 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52895 - "GET /builder/app/home_automation_agent?ts=1763151991683 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52894 - "GET /debug/trace/session/4874a7b9-57dc-4d06-bece-71e4d4aaaa90 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52895 - "GET /apps/home_automation_agent/eval_sets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52894 - "GET /apps/home_automation_agent/eval_results HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52895 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.66732 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52894 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147578.744541 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52896 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.668836 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52894 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.664961 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52895 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147492.554301 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52897 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_integration_suite_1763147949.375645 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52896 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_integration_suite_1763147949.374295 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52898 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.66816 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52894 - "GET /apps/home_automation_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52899 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.669558 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52895 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52908 - "POST /apps/home_automation_agent/eval_sets/home_automation_tests/add_session HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52908 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals HTTP/1.1" 200 OK
# /opt/homebrew/lib/python3.11/site-packages/google/adk/evaluation/metric_evaluator_registry.py:90: UserWarning: [EXPERIMENTAL] MetricEvaluatorRegistry: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   metric_evaluator_registry = MetricEvaluatorRegistry()
# /opt/homebrew/lib/python3.11/site-packages/google/adk/evaluation/local_eval_service.py:79: UserWarning: [EXPERIMENTAL] UserSimulatorProvider: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   user_simulator_provider: UserSimulatorProvider = UserSimulatorProvider(),
# /opt/homebrew/lib/python3.11/site-packages/google/adk/cli/adk_web_server.py:1123: UserWarning: [EXPERIMENTAL] LocalEvalService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   eval_service = LocalEvalService(
# /opt/homebrew/lib/python3.11/site-packages/google/adk/evaluation/user_simulator_provider.py:77: UserWarning: [EXPERIMENTAL] StaticUserSimulator: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   return StaticUserSimulator(static_conversation=eval_case.conversation)
# /opt/homebrew/lib/python3.11/site-packages/google/adk/evaluation/static_user_simulator.py:39: UserWarning: [EXPERIMENTAL] UserSimulator: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__(
# 2025-11-14 12:27:46,508 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 12:27:46,509 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:27:47,083 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:27:47,083 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting lights in bedroom to ON
# 2025-11-14 12:27:47,086 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:27:47,566 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:27:47,568 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 12:27:47,568 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763152067.568793.evalset_result.json
# INFO:     127.0.0.1:52921 - "POST /apps/home_automation_agent/eval_sets/home_automation_tests/run_eval HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52921 - "GET /apps/home_automation_agent/eval_results HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52921 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.66732 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52923 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147578.744541 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52924 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.668836 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52921 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.664961 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52925 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_integration_suite_1763147949.375645 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52926 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.66816 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52927 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.669558 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52923 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147492.554301 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52924 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152067.568793 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52927 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_integration_suite_1763147949.374295 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52925 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___cba34345-c684-471b-9ae6-0952904f196f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52921 - "GET /debug/trace/session/___eval___session___cba34345-c684-471b-9ae6-0952904f196f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52925 - "GET /debug/trace/660827e1-e937-4c6b-a9c9-c6c2b2b65158 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52921 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___cba34345-c684-471b-9ae6-0952904f196f/events/660827e1-e937-4c6b-a9c9-c6c2b2b65158/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52925 - "GET /debug/trace/f2019893-5da7-400b-895d-e6af1bce1b06 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52921 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___cba34345-c684-471b-9ae6-0952904f196f/events/f2019893-5da7-400b-895d-e6af1bce1b06/graph HTTP/1.1" 200 OK
# 2025-11-14 12:30:32,907 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 12:30:32,911 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:33,409 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:33,411 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 12:30:33,412 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763152233.412593.evalset_result.json
# INFO:     127.0.0.1:52967 - "POST /apps/home_automation_agent/eval_sets/home_automation_tests/run_eval HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52967 - "GET /apps/home_automation_agent/eval_results HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52967 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.66732 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52969 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147578.744541 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52970 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.668836 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52971 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_integration_suite_1763147949.375645 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52967 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.664961 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52972 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.66816 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52973 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.669558 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52969 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147492.554301 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52967 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152067.568793 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52972 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_integration_suite_1763147949.374295 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52973 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152233.412593 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52970 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___9fb304f4-0bf1-49ac-8d1a-649d9528b276 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52971 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/bedroom_light_status HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52969 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___9fb304f4-0bf1-49ac-8d1a-649d9528b276 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52970 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___9fb304f4-0bf1-49ac-8d1a-649d9528b276 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52971 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___9fb304f4-0bf1-49ac-8d1a-649d9528b276 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52969 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___9fb304f4-0bf1-49ac-8d1a-649d9528b276 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52970 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___9fb304f4-0bf1-49ac-8d1a-649d9528b276 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52971 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___9fb304f4-0bf1-49ac-8d1a-649d9528b276 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52969 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/bedroom_light_status HTTP/1.1" 200 OK
# 2025-11-14 12:30:46,388 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 12:30:46,389 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:46,390 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 12:30:46,391 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:46,393 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 12:30:46,394 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:46,394 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 12:30:46,395 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:46,856 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:46,856 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting desk lamp in office to ON
# 2025-11-14 12:30:46,858 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:46,868 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:46,868 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting desk lamp in office to ON
# 2025-11-14 12:30:46,869 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:46,946 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:46,946 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting all in all to OFF
# Tool Call: Setting all in all to ON
# 2025-11-14 12:30:46,947 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:47,200 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:47,200 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting lights in bedroom to ON
# 2025-11-14 12:30:47,201 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:47,293 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:47,294 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:47,322 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:47,323 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 12:30:47,323 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:47,330 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:47,331 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 12:30:47,332 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:47,727 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:47,737 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:47,737 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting lights in bedroom to ON
# 2025-11-14 12:30:47,739 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:47,787 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:47,787 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting TV in garage to OFF
# 2025-11-14 12:30:47,788 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:47,965 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:47,965 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting lights in bedroom to ON
# 2025-11-14 12:30:47,966 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 12:30:48,212 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:48,252 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:48,464 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 12:30:48,466 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 12:30:48,467 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 12:30:48,467 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 12:30:48,468 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 12:30:48,468 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 12:30:48,469 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 12:30:48,469 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 12:30:48,470 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763152248.4700968.evalset_result.json
# 2025-11-14 12:30:48,470 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763152248.470585.evalset_result.json
# 2025-11-14 12:30:48,472 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763152248.4721038.evalset_result.json
# 2025-11-14 12:30:48,472 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763152248.472708.evalset_result.json
# 2025-11-14 12:30:48,473 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763152248.473093.evalset_result.json
# 2025-11-14 12:30:48,473 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763152248.473624.evalset_result.json
# INFO:     127.0.0.1:52971 - "POST /apps/home_automation_agent/eval_sets/home_automation_tests/run_eval HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52971 - "GET /apps/home_automation_agent/eval_results HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52971 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.66732 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52977 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.472708 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52978 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.473624 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52971 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_integration_suite_1763147949.375645 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52979 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.473093 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52980 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147578.744541 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52981 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.668836 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52977 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.66816 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52971 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.669558 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52979 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.4721038 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52978 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.664961 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52980 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147492.554301 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52981 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.470585 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52977 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152067.568793 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52978 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.4700968 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52979 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_integration_suite_1763147949.374295 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52971 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152233.412593 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52980 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___4b140caa-644d-4180-8d5d-92647c32e6cd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52981 - "GET /debug/trace/session/___eval___session___4b140caa-644d-4180-8d5d-92647c32e6cd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52980 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/basic_device_control HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52981 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___1fbb8045-45b6-4982-9031-48f3616daefc HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52980 - "GET /debug/trace/session/___eval___session___1fbb8045-45b6-4982-9031-48f3616daefc HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/complex_multi_device_command HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___ea2717f6-5c32-489c-8636-309bb3126850 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___ea2717f6-5c32-489c-8636-309bb3126850 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___ea2717f6-5c32-489c-8636-309bb3126850 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___32b6d2d5-80bd-4d3e-a4f1-8578890691b7 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /debug/trace/session/___eval___session___32b6d2d5-80bd-4d3e-a4f1-8578890691b7 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___ea2717f6-5c32-489c-8636-309bb3126850 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___ea2717f6-5c32-489c-8636-309bb3126850 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___ea2717f6-5c32-489c-8636-309bb3126850 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___ea2717f6-5c32-489c-8636-309bb3126850 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___ea2717f6-5c32-489c-8636-309bb3126850 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___32b6d2d5-80bd-4d3e-a4f1-8578890691b7 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /debug/trace/session/___eval___session___32b6d2d5-80bd-4d3e-a4f1-8578890691b7 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/invalid_location_test HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52984 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/complex_multi_device_command HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52990 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___32b6d2d5-80bd-4d3e-a4f1-8578890691b7 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52990 - "GET /debug/trace/session/___eval___session___32b6d2d5-80bd-4d3e-a4f1-8578890691b7 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52992 - "GET /debug/trace/583d39dc-2f6a-449f-af54-c77afc8386d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52993 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___32b6d2d5-80bd-4d3e-a4f1-8578890691b7/events/583d39dc-2f6a-449f-af54-c77afc8386d9/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52992 - "GET /debug/trace/26794ac6-6544-4533-81b0-c93fad2c8d8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52993 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___32b6d2d5-80bd-4d3e-a4f1-8578890691b7/events/26794ac6-6544-4533-81b0-c93fad2c8d8d/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52996 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/invalid_location_test HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52997 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/complex_multi_device_command HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52997 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/bedroom_light_status HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52997 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/basic_device_control HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52997 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/ambiguous_device_reference1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52997 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/ambiguous_device_reference HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55077 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:55077 - "GET /dev-ui/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55077 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:55077 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# 2025-11-14 13:10:33,398 - INFO - adk_web_server.py:605 - New session created: 3e862234-dc6d-4f79-915f-7b0c4cecae09
# INFO:     127.0.0.1:57161 - "POST /apps/home_automation_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57162 - "GET /builder/app/home_automation_agent?ts=1763154633396 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57161 - "GET /apps/home_automation_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57162 - "GET /apps/home_automation_agent/users/user/sessions/3e862234-dc6d-4f79-915f-7b0c4cecae09 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57161 - "GET /debug/trace/session/3e862234-dc6d-4f79-915f-7b0c4cecae09 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57162 - "GET /apps/home_automation_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57203 - "GET /dev-ui/?app=home_automation_agent&session=3e862234-dc6d-4f79-915f-7b0c4cecae09&userId=user HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57203 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:57203 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57203 - "GET /apps/home_automation_agent/users/user/sessions/3e862234-dc6d-4f79-915f-7b0c4cecae09 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57204 - "GET /builder/app/home_automation_agent?ts=1763154646058 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57203 - "GET /debug/trace/session/3e862234-dc6d-4f79-915f-7b0c4cecae09 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57204 - "GET /apps/home_automation_agent/eval_sets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57203 - "GET /apps/home_automation_agent/eval_results HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57204 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.66732 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57203 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.472708 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57205 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.473624 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57203 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_integration_suite_1763147949.375645 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57204 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.66816 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57206 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.473093 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57205 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.669558 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57207 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147578.744541 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57203 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.4721038 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57206 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.664961 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57204 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147492.554301 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57208 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.668836 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57207 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.470585 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57205 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152067.568793 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57203 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.4700968 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57206 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_integration_suite_1763147949.374295 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57204 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152233.412593 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57208 - "GET /apps/home_automation_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57220 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57220 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/ambiguous_device_reference1 HTTP/1.1" 200 OK
# 2025-11-14 13:11:02,822 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 13:11:02,827 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 13:11:02,835 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 13:11:02,836 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 13:11:02,837 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 13:11:02,838 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 13:11:02,839 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 13:11:02,839 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 13:11:03,479 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 13:11:03,479 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting desk lamp in office to ON
# 2025-11-14 13:11:03,481 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 13:11:03,481 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 13:11:03,482 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 13:11:03,484 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 13:11:03,536 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 13:11:03,536 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting desk lamp in office to ON
# 2025-11-14 13:11:03,537 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 13:11:03,620 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 13:11:03,621 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 13:11:03,622 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 13:11:03,874 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 13:11:03,876 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 13:11:03,877 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 13:11:03,988 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 13:11:03,988 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting lights in bedroom to ON
# 2025-11-14 13:11:03,990 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 13:11:04,340 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 13:11:04,340 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting all in all to OFF
# Tool Call: Setting all in all to ON
# 2025-11-14 13:11:04,342 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 13:11:04,399 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 13:11:04,520 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 13:11:04,520 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting lights in bedroom to ON
# 2025-11-14 13:11:04,521 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 13:11:04,665 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 13:11:05,070 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 13:11:05,072 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 13:11:05,073 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 13:11:05,074 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 13:11:05,075 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 13:11:05,075 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 13:11:05,076 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 13:11:05,076 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 13:11:05,078 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763154665.0773382.evalset_result.json
# 2025-11-14 13:11:05,079 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763154665.078934.evalset_result.json
# 2025-11-14 13:11:05,079 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763154665.079301.evalset_result.json
# 2025-11-14 13:11:05,079 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763154665.079674.evalset_result.json
# 2025-11-14 13:11:05,080 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763154665.080296.evalset_result.json
# 2025-11-14 13:11:05,081 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_tests_1763154665.081146.evalset_result.json
# INFO:     127.0.0.1:57251 - "POST /apps/home_automation_agent/eval_sets/home_automation_tests/run_eval HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57251 - "GET /apps/home_automation_agent/eval_results HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57251 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.66732 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57262 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.472708 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57263 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763154665.080296 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57251 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147578.744541 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57264 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.473624 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57265 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.473093 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57266 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763154665.079674 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57262 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.668836 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57264 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_integration_suite_1763147949.375645 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57266 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763154665.079301 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57265 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763154665.081146 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57263 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.66816 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57251 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.669558 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57262 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.4721038 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57264 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147855.664961 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57266 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763147492.554301 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57265 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.470585 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57263 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152067.568793 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57251 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152248.4700968 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57262 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_integration_suite_1763147949.374295 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57264 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763154665.0773382 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57266 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763154665.078934 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57263 - "GET /apps/home_automation_agent/eval_results/home_automation_agent_home_automation_tests_1763152233.412593 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57262 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/ambiguous_device_reference1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57251 - "GET /apps/home_automation_agent/eval_sets/home_automation_tests/evals/ambiguous_device_reference HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57262 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___8b68d967-7122-4d5d-b7e0-225cc418381b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57251 - "GET /debug/trace/session/___eval___session___8b68d967-7122-4d5d-b7e0-225cc418381b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57328 - "GET /debug/trace/89f74f20-8bdc-48fb-82e1-e710d84d9ee2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57329 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___8b68d967-7122-4d5d-b7e0-225cc418381b/events/89f74f20-8bdc-48fb-82e1-e710d84d9ee2/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57350 - "GET /debug/trace/e4cb82fa-c0c1-4a68-b061-6e57f40578b7 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57351 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___8b68d967-7122-4d5d-b7e0-225cc418381b/events/e4cb82fa-c0c1-4a68-b061-6e57f40578b7/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57465 - "GET /debug/trace/89f74f20-8bdc-48fb-82e1-e710d84d9ee2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57466 - "GET /apps/home_automation_agent/users/user/sessions/___eval___session___8b68d967-7122-4d5d-b7e0-225cc418381b/events/89f74f20-8bdc-48fb-82e1-e710d84d9ee2/graph HTTP/1.1" 200 OK
# ^C
# INFO:     Shutting down
# INFO:     Finished server process [5799]
# ERROR:    Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.11/site-packages/uvicorn/_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "uvloop/loop.pyx", line 1512, in uvloop.loop.Loop.run_until_complete
#   File "uvloop/loop.pyx", line 1505, in uvloop.loop.Loop.run_until_complete
#   File "uvloop/loop.pyx", line 1379, in uvloop.loop.Loop.run_forever
#   File "uvloop/loop.pyx", line 557, in uvloop.loop.Loop._run
#   File "uvloop/loop.pyx", line 476, in uvloop.loop.Loop._on_idle
#   File "uvloop/cbhandles.pyx", line 83, in uvloop.loop.Handle._run
#   File "uvloop/cbhandles.pyx", line 63, in uvloop.loop.Handle._run
#   File "/opt/homebrew/lib/python3.11/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "/opt/homebrew/lib/python3.11/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.11/site-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/opt/homebrew/lib/python3.11/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/queues.py", line 158, in get
#     await getter
# asyncio.exceptions.CancelledError
#
#
# Aborted!

# %% [markdown]
# Once the ADK web UI starts, open the proxy link using the button in the previous cell.
#
# ‼️ **IMPORTANT: DO NOT SHARE THE PROXY LINK** with anyone - treat it as sensitive data as it contains your authentication token in the URL.

# %% [markdown]
# ### 3.2: Create Your First "Perfect" Test Case
#
# **👉 Do: In the ADK web UI:**
#
# 1. Click the public URL above to open the ADK web UI
# 2. Select "home_automation_agent" from the dropdown
# 3. **Have a normal conversation:** Type `Turn on the desk lamp in the office`
# 4. **Agent responds correctly** - controls device and confirms action
#
# **👉 Do: Save this as your first evaluation case:**
#
# 1. Navigate to the **Eval** tab on the right-hand panel
# 2. Click **Create Evaluation set** and name it `home_automation_tests`
# 3. In the `home_automation_tests` set, click the ">" arrow and click **Add current session**
# 4. Give it the case name `basic_device_control`
#
# **✅ Success!** You've just saved your first interaction as an evaluation case.

# %% [markdown]
# ![Create Test Cases](https://storage.googleapis.com/github-repo/kaggle-5days-ai/day4/eval-create-testcase.gif)

# %% [markdown]
# ### 3.3: Run the Evaluation
#
# **👉 Do: Run your first evaluation**
#
# Now, let's run the test case to see if the agent can replicate its previous success.
#
# 1. In the Eval tab, make sure your new test case is checked.
# 2. Click the Run Evaluation button.
# 3. The EVALUATION METRIC dialog will appear. For now, leave the default values and click Start.
# 4. The evaluation will run, and you should see a green Pass result in the Evaluation History. This confirms the agent's behavior matched the saved session.
#
# ‼️ **Understanding the Evaluation Metrics**
#
# When you run evaluation, you'll see two key scores:
#
# * **Response Match Score:** Measures how similar the agent's actual response is to the expected response. Uses text similarity algorithms to compare content. A score of 1.0 = perfect match, 0.0 = completely different.
#
# * **Tool Trajectory Score:** Measures whether the agent used the correct tools with correct parameters. Checks the sequence of tool calls against expected behavior. A score of 1.0 = perfect tool usage, 0.0 = wrong tools or parameters.
#
# **👉 Do: Analyze a Failure**
#
# Let's intentionally break the test to see what a failure looks like.
#
# 1. In the list of eval cases, click the Edit (pencil) icon next to your test case.
# 2. In the "Final Response" text box, change the expected text to something incorrect, like: `The desk lamp is off`.
# 3. Save the changes and re-run the evaluation.
# 4. This time, the result will be a red Fail. Hover your mouse over the "Fail" label. A tooltip will appear showing a side-by-side comparison of the Actual vs. Expected Output, highlighting exactly why the test failed (the final response didn't match).
# This immediate, detailed feedback is invaluable for debugging.

# %% [markdown]
# ![Evaluate](https://storage.googleapis.com/github-repo/kaggle-5days-ai/day4/eval-run-test.gif)

# %% [markdown]
# ### 3.4: (Optional) Create challenging test cases
#
# Now create more test cases to expose hidden problems:
#
# **Create these scenarios in separate conversations:**
#
# 1. **Ambiguous Commands:** `"Turn on the lights in the bedroom"`
#    - Save as a new test case: `ambiguous_device_reference`
#    - Run evaluation - it likely passes but the agent might be confused
#
# 2. **Invalid Locations:** `"Please turn off the TV in the garage"`
#    - Save as a new test case: `invalid_location_test`
#    - Run evaluation - the agent might try to control non-existent devices
#
# 3. **Complex Commands:** `"Turn off all lights and turn on security system"`
#    - Save as a new test case: `complex_multi_device_command`
#    - Run evaluation - the agent might attempt operations beyond its capabilities
#
# **The Problem You'll Discover:**
# Even when tests "pass," you can see the agent:
# - Makes assumptions about devices that don't exist
# - Gives responses that sound helpful but aren't accurate
# - Tries to control devices it shouldn't have access to

# %% [markdown]
# ## 🤔 What am I missing?
#
# ❌ **Web UI Limitation:** So far, we've seen how to create and evaluate test cases in the ADK web UI. The web UI is great for interactive test creation, but testing one conversation at a time doesn't scale.
#
# ❓ **The Question:** How do I proactively detect regressions in my agent's performance?
#
# Let's answer that question in the next section!
#
# ---

# %% [markdown]
# ## ‼️ **Stop the ADK web UI** 🛑
#
# **In order to run cells in the remainder of this notebook,** please stop the running cell where you started `adk web` in Section 3.1.
#
# Otherwise that running cell will block / prevent other cells from running as long as the ADK web UI is running.

# %% [markdown]
# ---
# ## 📈 Section 4: Systematic Evaluation
#
# Regression testing is the practice of re-running existing tests to ensure that new changes haven't broken previously working functionality.
#
# ADK provides two methods to do automatic regression and batch testing: using [pytest](https://google.github.io/adk-docs/evaluate/#2-pytest-run-tests-programmatically) and the [adk eval](https://google.github.io/adk-docs/evaluate/#3-adk-eval-run-evaluations-via-the-cli) CLI command. In this section, we'll use the CLI command. For more information on the `pytest` approach, refer to the links in the resource section at the end of this notebook.
#
# The following image shows the overall process of evaluation. **At a high-level, there are four steps to evaluate:**
#
# 1) **Create an evaluation configuration** - define metrics or what you want to measure
# 2) **Create test cases** - sample test cases to compare against
# 3) **Run the agent with test query**
# 4) **Compare the results**

# %% [markdown]
# ![Evaluate](https://storage.googleapis.com/github-repo/kaggle-5days-ai/day4/evaluate_agent.png)

# %% [markdown]
# ### 4.1: Create evaluation configuration
#
# This optional file lets us define the pass/fail thresholds. Create `test_config.json` in the root directory.

# %%
import json

# Create evaluation configuration with basic criteria
eval_config = {
    "criteria": {
        "tool_trajectory_avg_score": 1.0,  # Perfect tool usage required
        "response_match_score": 0.9,  # 80% text similarity threshold
    }
}

with open("home_automation_agent/test_config.json", "w") as f:
    json.dump(eval_config, f, indent=2)

print("✅ Evaluation configuration created!")
print("\n📊 Evaluation Criteria:")
print("• tool_trajectory_avg_score: 1.0 - Requires exact tool usage match")
print("• response_match_score: 0.9 - Requires 90% text similarity")
print("\n🎯 What this evaluation will catch:")
print("✅ Incorrect tool usage (wrong device, location, or status)")
print("✅ Poor response quality and communication")
print("✅ Deviations from expected behavior patterns")
# Out:
# ✅ Evaluation configuration created!
#
# 📊 Evaluation Criteria:
# • tool_trajectory_avg_score: 1.0 - Requires exact tool usage match
# • response_match_score: 0.9 - Requires 90% text similarity
#
# 🎯 What this evaluation will catch:
# ✅ Incorrect tool usage (wrong device, location, or status)
# ✅ Poor response quality and communication
# ✅ Deviations from expected behavior patterns

# %% [markdown]
# ### 4.2: Create test cases
#
# This file (`integration.evalset.json`) will contain multiple test cases (sessions).
#
# This evaluation set can be created synthetically or from the conversation sessions in the ADK web UI.
#
# **Tip:** To persist the conversations from the ADK web UI, simply create an evalset in the UI and add the current session to it. All the conversations in that session will be auto-converted to an evalset and downloaded locally.

# %%
# Create evaluation test cases that reveal tool usage and response quality problems
test_cases = {
    "eval_set_id": "home_automation_integration_suite",
    "eval_cases": [
        {
            "eval_id": "living_room_light_on",
            "conversation": [
                {
                    "user_content": {
                        "parts": [
                            {"text": "Please turn on the floor lamp in the living room"}
                        ]
                    },
                    "final_response": {
                        "parts": [
                            {
                                "text": "Successfully set the floor lamp in the living room to on."
                            }
                        ]
                    },
                    "intermediate_data": {
                        "tool_uses": [
                            {
                                "name": "set_device_status",
                                "args": {
                                    "location": "living room",
                                    "device_id": "floor lamp",
                                    "status": "ON",
                                },
                            }
                        ]
                    },
                }
            ],
        },
        {
            "eval_id": "kitchen_on_off_sequence",
            "conversation": [
                {
                    "user_content": {
                        "parts": [{"text": "Switch on the main light in the kitchen."}]
                    },
                    "final_response": {
                        "parts": [
                            {
                                "text": "Successfully set the main light in the kitchen to on."
                            }
                        ]
                    },
                    "intermediate_data": {
                        "tool_uses": [
                            {
                                "name": "set_device_status",
                                "args": {
                                    "location": "kitchen",
                                    "device_id": "main light",
                                    "status": "ON",
                                },
                            }
                        ]
                    },
                }
            ],
        },
    ],
}

# %% [markdown]
# Let's write the test cases to the `integration.evalset.json` in our agent's root directory.

# %%
import json

with open("home_automation_agent/integration.evalset.json", "w") as f:
    json.dump(test_cases, f, indent=2)

print("✅ Evaluation test cases created")
print("\n🧪 Test scenarios:")
for case in test_cases["eval_cases"]:
    user_msg = case["conversation"][0]["user_content"]["parts"][0]["text"]
    print(f"• {case['eval_id']}: {user_msg}")

print("\n📊 Expected results:")
print("• basic_device_control: Should pass both criteria")
print(
    "• wrong_tool_usage_test: May fail tool_trajectory if agent uses wrong parameters"
)
print(
    "• poor_response_quality_test: May fail response_match if response differs too much"
)
# Out:
# ✅ Evaluation test cases created
#
# 🧪 Test scenarios:
# • living_room_light_on: Please turn on the floor lamp in the living room
# • kitchen_on_off_sequence: Switch on the main light in the kitchen.
#
# 📊 Expected results:
# • basic_device_control: Should pass both criteria
# • wrong_tool_usage_test: May fail tool_trajectory if agent uses wrong parameters
# • poor_response_quality_test: May fail response_match if response differs too much

# %% [markdown]
# ### 4.3: Run CLI Evaluation
#
# Execute the `adk eval` command, pointing it to your agent directory, the evalset, and the config file.

# %%
print("🚀 Run this command to execute evaluation:")
# !adk eval home_automation_agent home_automation_agent/integration.evalset.json --config_file_path=home_automation_agent/test_config.json --print_detailed_results
# Out:
# 🚀 Run this command to execute evaluation:
# /opt/homebrew/lib/python3.11/site-packages/google/adk/evaluation/metric_evaluator_registry.py:90: UserWarning: [EXPERIMENTAL] MetricEvaluatorRegistry: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   metric_evaluator_registry = MetricEvaluatorRegistry()
# /opt/homebrew/lib/python3.11/site-packages/google/adk/evaluation/local_eval_service.py:79: UserWarning: [EXPERIMENTAL] UserSimulatorProvider: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   user_simulator_provider: UserSimulatorProvider = UserSimulatorProvider(),
# Using evaluation criteria: criteria={'tool_trajectory_avg_score': 1.0, 'response_match_score': 0.9} user_simulator_config=None
# /opt/homebrew/lib/python3.11/site-packages/google/adk/cli/cli_tools_click.py:650: UserWarning: [EXPERIMENTAL] UserSimulatorProvider: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   user_simulator_provider = UserSimulatorProvider(
# /opt/homebrew/lib/python3.11/site-packages/google/adk/cli/cli_tools_click.py:655: UserWarning: [EXPERIMENTAL] LocalEvalService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   eval_service = LocalEvalService(
# /opt/homebrew/lib/python3.11/site-packages/google/adk/evaluation/user_simulator_provider.py:77: UserWarning: [EXPERIMENTAL] StaticUserSimulator: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   return StaticUserSimulator(static_conversation=eval_case.conversation)
# /opt/homebrew/lib/python3.11/site-packages/google/adk/evaluation/static_user_simulator.py:39: UserWarning: [EXPERIMENTAL] UserSimulator: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__(
# 2025-11-14 11:19:08,269 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 11:19:08,336 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 11:19:08,339 - INFO - plugin_manager.py:96 - Plugin 'request_intercepter_plugin' registered.
# 2025-11-14 11:19:08,340 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 11:19:08,875 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 11:19:08,875 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 2025-11-14 11:19:08,876 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 11:19:08,876 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Tool Call: Setting floor lamp in living room to ON
# Tool Call: Setting main light in kitchen to ON
# 2025-11-14 11:19:08,879 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 11:19:08,881 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-14 11:19:09,346 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 11:19:09,370 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-14 11:19:09,372 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 11:19:09,373 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-14 11:19:09,374 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_integration_suite_1763147949.374295.evalset_result.json
# 2025-11-14 11:19:09,375 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /Users/tvo/Documents/portfolio/college-notes/google-adk/home_automation_agent/.adk/eval_history/home_automation_agent_home_automation_integration_suite_1763147949.375645.evalset_result.json
# *********************************************************************
# Eval Run Summary
# home_automation_integration_suite:
#   Tests passed: 0
#   Tests failed: 2
# ********************************************************************
# Eval Set Id: home_automation_integration_suite
# Eval Id: living_room_light_on
# Overall Eval Status: FAILED
# ---------------------------------------------------------------------
# Metric: tool_trajectory_avg_score, Status: PASSED, Score: 1.0, Threshold: 1.0
# ---------------------------------------------------------------------
# Metric: response_match_score, Status: FAILED, Score: 0.7272727272727273, Threshold: 0.9
# ---------------------------------------------------------------------
# Invocation Details:
# +----+--------------------------+--------------------------+-----------------------+---------------------------+---------------------------+-----------------------------+------------------------+
# |    | prompt                   | expected_response        | actual_response       | expected_tool_calls       | actual_tool_calls         | tool_trajectory_avg_score   | response_match_score   |
# +====+==========================+==========================+=======================+===========================+===========================+=============================+========================+
# |  0 | Please turn on the floor | Successfully set the     | The floor lamp in the | id=None args={'location': | id='adk- bb5e7727-6a29-41 | Status: PASSED, Score:      | Status: FAILED, Score: |
# |    | lamp in the living room  | floor lamp in the living | living room has been  | 'living room',            | d6-a160-00fc7d3c2ccc'     | 1.0                         | 0.7272727272727273     |
# |    |                          | room to on.              | turned on.            | 'device_id': 'floor       | args={'location': 'living |                             |                        |
# |    |                          |                          |                       | lamp', 'status': 'ON'}    | room', 'device_id':       |                             |                        |
# |    |                          |                          |                       | name='set_device_status'  | 'floor lamp', 'status':   |                             |                        |
# |    |                          |                          |                       |                           | 'ON'}                     |                             |                        |
# |    |                          |                          |                       |                           | name='set_device_status'  |                             |                        |
# +----+--------------------------+--------------------------+-----------------------+---------------------------+---------------------------+-----------------------------+------------------------+
#
#
#
# ********************************************************************
# Eval Set Id: home_automation_integration_suite
# Eval Id: kitchen_on_off_sequence
# Overall Eval Status: FAILED
# ---------------------------------------------------------------------
# Metric: tool_trajectory_avg_score, Status: PASSED, Score: 1.0, Threshold: 1.0
# ---------------------------------------------------------------------
# Metric: response_match_score, Status: FAILED, Score: 0.7, Threshold: 0.9
# ---------------------------------------------------------------------
# Invocation Details:
# +----+--------------------------+---------------------------+---------------------------+---------------------------+---------------------------+-----------------------------+------------------------+
# |    | prompt                   | expected_response         | actual_response           | expected_tool_calls       | actual_tool_calls         | tool_trajectory_avg_score   | response_match_score   |
# +====+==========================+===========================+===========================+===========================+===========================+=============================+========================+
# |  0 | Switch on the main light | Successfully set the main | The main light in the     | id=None args={'location': | id='adk-0bba1915-3ee9-4eb | Status: PASSED, Score:      | Status: FAILED, Score: |
# |    | in the kitchen.          | light in the kitchen to   | kitchen has been switched | 'kitchen', 'device_id':   | a-97de- 85b1de9e8151'     | 1.0                         | 0.7                    |
# |    |                          | on.                       | on.                       | 'main light', 'status':   | args={'location':         |                             |                        |
# |    |                          |                           |                           | 'ON'}                     | 'kitchen', 'status':      |                             |                        |
# |    |                          |                           |                           | name='set_device_status'  | 'ON', 'device_id': 'main  |                             |                        |
# |    |                          |                           |                           |                           | light'}                   |                             |                        |
# |    |                          |                           |                           |                           | name='set_device_status'  |                             |                        |
# +----+--------------------------+---------------------------+---------------------------+---------------------------+---------------------------+-----------------------------+------------------------+

# %% [markdown]
# ### 4.4: Analyzing sample evaluation results
#
# The command will run all test cases and print a summary. The `--print_detailed_results` flag provides a turn-by-turn breakdown of each test, showing scores and a diff for any failures.

# %%
# Analyzing evaluation results - the data science approach
print("📊 Understanding Evaluation Results:")
print()
print("🔍 EXAMPLE ANALYSIS:")
print()
print("Test Case: living_room_light_on")
print("  ❌ response_match_score: 0.45/0.90")
print("  ✅ tool_trajectory_avg_score: 1.0/1.0")
print()
print("📈 What this tells us:")
print("• TOOL USAGE: Perfect - Agent used correct tool with correct parameters")
print("• RESPONSE QUALITY: Poor - Response text too different from expected")
print("• ROOT CAUSE: Agent's communication style, not functionality")
print()
print("🎯 ACTIONABLE INSIGHTS:")
print("1. Technical capability works (tool usage perfect)")
print("2. Communication needs improvement (response quality failed)")
print("3. Fix: Update agent instructions for clearer language or constrained response.")
print()
# Out:
# 📊 Understanding Evaluation Results:
#
# 🔍 EXAMPLE ANALYSIS:
#
# Test Case: living_room_light_on
#   ❌ response_match_score: 0.45/0.90
#   ✅ tool_trajectory_avg_score: 1.0/1.0
#
# 📈 What this tells us:
# • TOOL USAGE: Perfect - Agent used correct tool with correct parameters
# • RESPONSE QUALITY: Poor - Response text too different from expected
# • ROOT CAUSE: Agent's communication style, not functionality
#
# 🎯 ACTIONABLE INSIGHTS:
# 1. Technical capability works (tool usage perfect)
# 2. Communication needs improvement (response quality failed)
# 3. Fix: Update agent instructions for clearer language or constrained response.

# %%
# Parallel + Evaluator Workflow

# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)


# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")


# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)


parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

root_agent = SequentialAgent(
    name="ResearchSystem + Evaluator Agent",
    sub_agents=[parallel_research_team, aggregator_agent],
)

runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)

# %% [markdown]
# ---
# ## 📚 Section 5: User Simulation (Optional)
#
# While **traditional evaluation methods rely on fixed test cases**, real-world conversations are dynamic and unpredictable. This is where User Simulation comes in.
#
# User Simulation is a powerful feature in ADK that addresses the limitations of static evaluation. Instead of using pre-defined, fixed user prompts, User Simulation employs a generative AI model (like Gemini) to **dynamically generate user prompts during the evaluation process.**
#
# ### ❓ How it works
#
# * You define a `ConversationScenario` that outlines the user's overall conversational goals and a `conversation_plan` to guide the dialogue.
# * A large language model (LLM) then acts as a simulated user, using this plan and the ongoing conversation history to generate realistic and varied prompts.
# * This allows for more comprehensive testing of your agent's ability to handle unexpected turns, maintain context, and achieve complex goals in a more natural, unpredictable conversational flow.
#
# User Simulation helps you uncover edge cases and improve your agent's robustness in ways that static test cases often miss.
#
# ### 👉 Exercise
#
# Now that you understand the power of User Simulation for dynamic agent evaluation, here's an exercise to apply it:
#
# Apply the **User Simulation** feature to your agent. Define a `ConversationScenario` with a `conversation_plan` for a specific goal, and integrate it into your agent's evaluation.
#
# **⭐ Refer to this [documentation](https://google.github.io/adk-docs/evaluate/user-sim/) to learn how to do it.**

# %% [markdown]
# ## 🏆 Congratulations!
#
# ### You've learned
#
# - ✅ Interactive test creation and analysis in the ADK web UI
# - ✅ Tool trajectory and response metrics
# - ✅ Automated regression testing using `adk eval` CLI command
# - ✅ How to analyze evaluation results and fix agents based on it
#
# **ℹ️ Note: No submission required!**
#
# This notebook is for your hands-on practice and learning only. You **do not** need to submit it anywhere to complete the course.

# %% [markdown]
# ### 📚 Resources
# * [ADK Evaluation overview](https://google.github.io/adk-docs/evaluate/)
# * Different [evaluation criteria](https://google.github.io/adk-docs/evaluate/criteria/)
# * [Pytest based Evaluation](https://google.github.io/adk-docs/evaluate/#2-pytest-run-tests-programmatically)
#
# ### Advanced Evaluation
# For production deployments, ADK supports [advanced criteria](https://docs.cloud.google.com/vertex-ai/generative-ai/docs/models/determine-eval) like `safety_v1` and `hallucinations_v1` (requires Google Cloud credentials).
#
# ### 🎯 Next Steps
# Ready for the next challenge? Stay tuned for the final Day 5 notebooks where we'll bring it all home! 😎
#
# We'll learn how to **Deploy an Agent to Production** and extend them with **Agent2Agent Protocol.**

# %% [markdown]
# ---
#
# <div align="center">
#   <table>
#     <tr>
#       <th style="text-align:center">Authors</th>
#     </tr>
#     <tr>
#       <td style="text-align:center"><a href="https://www.linkedin.com/in/sitalakshmi04/">Sita Lakshmi Sangameswaran</a></td>
#     </tr>
#     <tr>
#       <td style="text-align:center"><a href="https://www.linkedin.com/in/ivan-nardini/">Ivan Nardini</a></td>
#     </tr>
#   </table>
# </div>
